# %%
"""
Optuna example that optimizes multi-layer perceptrons using PyTorch.

In this example, we optimize the validation accuracy of fashion product recognition using
PyTorch and FashionMNIST. We optimize the neural network architecture as well as the optimizer
configuration. As it is too time consuming to use the whole FashionMNIST dataset,
we here use a small subset of it.

"""

import os

import optuna
from optuna.trial import TrialState
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
from torchvision import datasets
from torchvision import transforms


DEVICE = torch.device("cpu")
BATCHSIZE = 128
CLASSES = 10
DIR = os.getcwd()
EPOCHS = 10
N_TRAIN_EXAMPLES = BATCHSIZE * 30
N_VALID_EXAMPLES = BATCHSIZE * 10


def define_model(trial):
    # We optimize the number of layers, hidden units and dropout ratio in each layer.
    n_layers = trial.suggest_int("n_layers", 1, 3)
    layers = []

    in_features = 28 * 28
    for i in range(n_layers):
        out_features = trial.suggest_int("n_units_l{}".format(i), 4, 128)
        layers.append(nn.Linear(in_features, out_features))
        layers.append(nn.ReLU())
        p = trial.suggest_float("dropout_l{}".format(i), 0.2, 0.5)
        layers.append(nn.Dropout(p))

        in_features = out_features
    layers.append(nn.Linear(in_features, CLASSES))
    layers.append(nn.LogSoftmax(dim=1))

    return nn.Sequential(*layers)


def get_mnist():
    # Load FashionMNIST dataset.
    train_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST(DIR, train=True, download=True, transform=transforms.ToTensor()),
        batch_size=BATCHSIZE,
        shuffle=True,
    )
    valid_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST(DIR, train=False, transform=transforms.ToTensor()),
        batch_size=BATCHSIZE,
        shuffle=True,
    )

    return train_loader, valid_loader


def objective(trial):
    # Generate the model.
    model = define_model(trial).to(DEVICE)

    # Generate the optimizers.
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=lr)

    # Get the FashionMNIST dataset.
    train_loader, valid_loader = get_mnist()

    # Training of the model.
    for epoch in range(EPOCHS):
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            # Limiting training data for faster epochs.
            if batch_idx * BATCHSIZE >= N_TRAIN_EXAMPLES:
                break

            data, target = data.view(data.size(0), -1).to(DEVICE), target.to(DEVICE)

            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()

        # Validation of the model.
        model.eval()
        correct = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(valid_loader):
                # Limiting validation data.
                if batch_idx * BATCHSIZE >= N_VALID_EXAMPLES:
                    break
                data, target = data.view(data.size(0), -1).to(DEVICE), target.to(DEVICE)
                output = model(data)
                # Get the index of the max log-probability.
                pred = output.argmax(dim=1, keepdim=True)
                correct += pred.eq(target.view_as(pred)).sum().item()

        accuracy = correct / min(len(valid_loader.dataset), N_VALID_EXAMPLES)

        trial.report(accuracy, epoch)

        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return accuracy


if __name__ == "__main__":
    study = optuna.create_study(direction="maximize", storage="sqlite:///db.sqlite3", study_name="optuna-test")
    study.optimize(objective, n_trials=100, timeout=600)

    pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
    complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

    print("Study statistics: ")
    print("  Number of finished trials: ", len(study.trials))
    print("  Number of pruned trials: ", len(pruned_trials))
    print("  Number of complete trials: ", len(complete_trials))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: ", trial.value)

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2023-07-11 21:12:45,813] A new study created in RDB with name: optuna-test
# [I 2023-07-11 21:12:47,737] Trial 0 finished with value: 0.54921875 and parameters: {'dropout_l0': 0.3607961550097868, 'dropout_l1': 0.44227608855429357, 'dropout_l2': 0.34773640421255436, 'lr': 0.00041882388624843073, 'n_layers': 3, 'n_units_l0': 108, 'n_units_l1': 5, 'n_units_l2': 50, 'optimizer': 'RMSprop'}. Best is trial 0 with value: 0.54921875.
# [I 2023-07-11 21:12:49,396] Trial 1 finished with value: 0.79609375 and parameters: {'dropout_l0': 0.2824495265455409, 'lr': 0.0005570753605918931, 'n_layers': 1, 'n_units_l0': 44, 'optimizer': 'RMSprop'}. Best is trial 1 with value: 0.79609375.
# [I 2023-07-11 21:12:50,998] Trial 2 finished with value: 0.378125 and parameters: {'dropout_l0': 0.299856243680077, 'lr': 7.272059060367414e-05, 'n_layers': 1, 'n_units_l0': 7, 'optimizer': 'Adam'}. Best is trial 1 with value: 0.79609375.
# [I 2023-07-11 21:12:52,668] Trial 3 finished with value: 0.125 and parameters: {'dropout_l0': 0.3334428642017303, 'dropout_l1': 0.21477725615345133, 'lr': 0.00017055063547117007, 'n_layers': 2, 'n_units_l0': 31, 'n_units_l1': 122, 'optimizer': 'SGD'}. Best is trial 1 with value: 0.79609375.
# [I 2023-07-11 21:12:54,430] Trial 4 finished with value: 0.76328125 and parameters: {'dropout_l0': 0.40703082384589745, 'dropout_l1': 0.21635656306482243, 'lr': 0.013609669594990341, 'n_layers': 2, 'n_units_l0': 30, 'n_units_l1': 127, 'optimizer': 'Adam'}. Best is trial 1 with value: 0.79609375.
# [I 2023-07-11 21:12:54,634] Trial 5 pruned.
# [I 2023-07-11 21:12:54,848] Trial 6 pruned.
# [I 2023-07-11 21:12:55,034] Trial 7 pruned.
# [I 2023-07-11 21:12:55,251] Trial 8 pruned.
# [I 2023-07-11 21:12:57,109] Trial 9 finished with value: 0.69765625 and parameters: {'dropout_l0': 0.34720374901117357, 'dropout_l1': 0.38724807867568034, 'dropout_l2': 0.2239795778456709, 'lr': 0.02438203538341735, 'n_layers': 3, 'n_units_l0': 115, 'n_units_l1': 76, 'n_units_l2': 59, 'optimizer': 'Adam'}. Best is trial 1 with value: 0.79609375.
# [I 2023-07-11 21:12:57,320] Trial 10 pruned.
# [I 2023-07-11 21:12:58,995] Trial 11 finished with value: 0.80390625 and parameters: {'dropout_l0': 0.2656359381959792, 'lr': 0.002691574937928016, 'n_layers': 1, 'n_units_l0': 54, 'optimizer': 'RMSprop'}. Best is trial 11 with value: 0.80390625.
# [I 2023-07-11 21:13:00,666] Trial 12 finished with value: 0.8125 and parameters: {'dropout_l0': 0.25842904429208896, 'lr': 0.0024330008067201606, 'n_layers': 1, 'n_units_l0': 54, 'optimizer': 'RMSprop'}. Best is trial 12 with value: 0.8125.
# [I 2023-07-11 21:13:02,860] Trial 13 finished with value: 0.7953125 and parameters: {'dropout_l0': 0.21380076309936585, 'lr': 0.004898732534420753, 'n_layers': 1, 'n_units_l0': 71, 'optimizer': 'RMSprop'}. Best is trial 12 with value: 0.8125.
# [I 2023-07-11 21:13:03,118] Trial 14 pruned.
# [I 2023-07-11 21:13:04,982] Trial 15 finished with value: 0.82890625 and parameters: {'dropout_l0': 0.25752568865611364, 'lr': 0.0020638319841779483, 'n_layers': 1, 'n_units_l0': 71, 'optimizer': 'RMSprop'}. Best is trial 15 with value: 0.82890625.
# [I 2023-07-11 21:13:05,203] Trial 16 pruned.
# [I 2023-07-11 21:13:07,460] Trial 17 finished with value: 0.825 and parameters: {'dropout_l0': 0.23471590790092978, 'lr': 0.0013141739856979777, 'n_layers': 1, 'n_units_l0': 94, 'optimizer': 'RMSprop'}. Best is trial 15 with value: 0.82890625.
# [I 2023-07-11 21:13:09,539] Trial 18 finished with value: 0.80234375 and parameters: {'dropout_l0': 0.23347026853410568, 'lr': 0.001311313889146712, 'n_layers': 1, 'n_units_l0': 95, 'optimizer': 'RMSprop'}. Best is trial 15 with value: 0.82890625.
# [I 2023-07-11 21:13:09,784] Trial 19 pruned.
# [I 2023-07-11 21:13:11,479] Trial 20 finished with value: 0.8046875 and parameters: {'dropout_l0': 0.23712483726406708, 'lr': 0.0008852259788109499, 'n_layers': 1, 'n_units_l0': 95, 'optimizer': 'RMSprop'}. Best is trial 15 with value: 0.82890625.
# [I 2023-07-11 21:13:12,169] Trial 21 pruned.
# [I 2023-07-11 21:13:12,373] Trial 22 pruned.
# [I 2023-07-11 21:13:12,719] Trial 23 pruned.
# [I 2023-07-11 21:13:12,929] Trial 24 pruned.
# [I 2023-07-11 21:13:14,548] Trial 25 finished with value: 0.83828125 and parameters: {'dropout_l0': 0.20112009020439503, 'lr': 0.0009530525366253284, 'n_layers': 1, 'n_units_l0': 75, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:14,748] Trial 26 pruned.
# [I 2023-07-11 21:13:14,957] Trial 27 pruned.
# [I 2023-07-11 21:13:15,154] Trial 28 pruned.
# [I 2023-07-11 21:13:15,356] Trial 29 pruned.
# [I 2023-07-11 21:13:15,580] Trial 30 pruned.
# [I 2023-07-11 21:13:15,774] Trial 31 pruned.
# [I 2023-07-11 21:13:15,970] Trial 32 pruned.
# [I 2023-07-11 21:13:16,161] Trial 33 pruned.
# [I 2023-07-11 21:13:16,359] Trial 34 pruned.
# [I 2023-07-11 21:13:17,565] Trial 35 pruned.
# [I 2023-07-11 21:13:17,774] Trial 36 pruned.
# [I 2023-07-11 21:13:17,966] Trial 37 pruned.
# [I 2023-07-11 21:13:18,167] Trial 38 pruned.
# [I 2023-07-11 21:13:18,364] Trial 39 pruned.
# [I 2023-07-11 21:13:18,572] Trial 40 pruned.
# [I 2023-07-11 21:13:20,218] Trial 41 finished with value: 0.81953125 and parameters: {'dropout_l0': 0.23874056601249266, 'lr': 0.0007127865358657602, 'n_layers': 1, 'n_units_l0': 97, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:21,968] Trial 42 finished with value: 0.8078125 and parameters: {'dropout_l0': 0.24101279665192704, 'lr': 0.0011352417296019135, 'n_layers': 1, 'n_units_l0': 102, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:22,174] Trial 43 pruned.
# [I 2023-07-11 21:13:22,742] Trial 44 pruned.
# [I 2023-07-11 21:13:22,954] Trial 45 pruned.
# [I 2023-07-11 21:13:23,633] Trial 46 pruned.
# [I 2023-07-11 21:13:25,295] Trial 47 finished with value: 0.80859375 and parameters: {'dropout_l0': 0.31855668060376663, 'lr': 0.0029404795767119605, 'n_layers': 1, 'n_units_l0': 68, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:25,494] Trial 48 pruned.
# [I 2023-07-11 21:13:27,274] Trial 49 finished with value: 0.79296875 and parameters: {'dropout_l0': 0.25976549267933113, 'lr': 0.0012006310661245984, 'n_layers': 1, 'n_units_l0': 93, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:27,503] Trial 50 pruned.
# [I 2023-07-11 21:13:28,403] Trial 51 pruned.
# [I 2023-07-11 21:13:30,608] Trial 52 finished with value: 0.7921875 and parameters: {'dropout_l0': 0.2369360618065507, 'lr': 0.001465421576265663, 'n_layers': 1, 'n_units_l0': 56, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:30,842] Trial 53 pruned.
# [I 2023-07-11 21:13:31,057] Trial 54 pruned.
# [I 2023-07-11 21:13:31,255] Trial 55 pruned.
# [I 2023-07-11 21:13:31,457] Trial 56 pruned.
# [I 2023-07-11 21:13:31,684] Trial 57 pruned.
# [I 2023-07-11 21:13:31,906] Trial 58 pruned.
# [I 2023-07-11 21:13:32,274] Trial 59 pruned.
# [I 2023-07-11 21:13:32,561] Trial 60 pruned.
# [I 2023-07-11 21:13:34,424] Trial 61 finished with value: 0.8296875 and parameters: {'dropout_l0': 0.24077993735537168, 'lr': 0.0011660596835088395, 'n_layers': 1, 'n_units_l0': 101, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:34,984] Trial 62 pruned.
# [I 2023-07-11 21:13:36,161] Trial 63 pruned.
# [I 2023-07-11 21:13:36,717] Trial 64 pruned.
# [I 2023-07-11 21:13:37,085] Trial 65 pruned.
# [I 2023-07-11 21:13:37,773] Trial 66 pruned.
# [I 2023-07-11 21:13:37,978] Trial 67 pruned.
# [I 2023-07-11 21:13:38,182] Trial 68 pruned.
# [I 2023-07-11 21:13:38,381] Trial 69 pruned.
# [I 2023-07-11 21:13:38,922] Trial 70 pruned.
# [I 2023-07-11 21:13:40,648] Trial 71 finished with value: 0.82265625 and parameters: {'dropout_l0': 0.23924443268800016, 'lr': 0.0010797111364968053, 'n_layers': 1, 'n_units_l0': 102, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:41,354] Trial 72 pruned.
# [I 2023-07-11 21:13:41,726] Trial 73 pruned.
# [I 2023-07-11 21:13:43,399] Trial 74 finished with value: 0.815625 and parameters: {'dropout_l0': 0.2252105590220451, 'lr': 0.0022340943028261143, 'n_layers': 1, 'n_units_l0': 106, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:43,604] Trial 75 pruned.
# [I 2023-07-11 21:13:43,806] Trial 76 pruned.
# [I 2023-07-11 21:13:44,006] Trial 77 pruned.
# [I 2023-07-11 21:13:44,209] Trial 78 pruned.
# [I 2023-07-11 21:13:44,757] Trial 79 pruned.
# [I 2023-07-11 21:13:44,990] Trial 80 pruned.
# [I 2023-07-11 21:13:45,190] Trial 81 pruned.
# [I 2023-07-11 21:13:46,834] Trial 82 finished with value: 0.81796875 and parameters: {'dropout_l0': 0.26118791674726327, 'lr': 0.0022509291694839226, 'n_layers': 1, 'n_units_l0': 72, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:47,033] Trial 83 pruned.
# [I 2023-07-11 21:13:47,234] Trial 84 pruned.
# [I 2023-07-11 21:13:47,434] Trial 85 pruned.
# [I 2023-07-11 21:13:49,168] Trial 86 finished with value: 0.82578125 and parameters: {'dropout_l0': 0.22868791833285726, 'lr': 0.0020639504466963767, 'n_layers': 1, 'n_units_l0': 108, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:49,394] Trial 87 pruned.
# [I 2023-07-11 21:13:49,660] Trial 88 pruned.
# [I 2023-07-11 21:13:52,784] Trial 89 finished with value: 0.8296875 and parameters: {'dropout_l0': 0.24421622235247967, 'lr': 0.001295312651948983, 'n_layers': 1, 'n_units_l0': 112, 'optimizer': 'RMSprop'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:13:53,425] Trial 90 pruned.
# [I 2023-07-11 21:13:53,644] Trial 91 pruned.
# [I 2023-07-11 21:13:54,899] Trial 92 pruned.
# [I 2023-07-11 21:13:56,205] Trial 93 pruned.
# [I 2023-07-11 21:13:56,453] Trial 94 pruned.
# [I 2023-07-11 21:13:56,658] Trial 95 pruned.
# [I 2023-07-11 21:13:58,539] Trial 96 pruned.
# [I 2023-07-11 21:13:59,291] Trial 97 pruned.
# [I 2023-07-11 21:14:01,047] Trial 98 finished with value: 0.825 and parameters: {'dropout_l0': 0.2001403042272708, 'lr': 0.0023778405063175126, 'n_layers': 1, 'n_units_l0': 96, 'optimizer': 'Adam'}. Best is trial 25 with value: 0.83828125.
# [I 2023-07-11 21:14:01,597] Trial 99 pruned.
# Study statistics:
#   Number of finished trials:  100
#   Number of pruned trials:  74
#   Number of complete trials:  26
# Best trial:
#   Value:  0.83828125
#   Params:
#     dropout_l0: 0.20112009020439503
#     lr: 0.0009530525366253284
#     n_layers: 1
#     n_units_l0: 75
#     optimizer: RMSprop
